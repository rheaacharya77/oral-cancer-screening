# %% [markdown]
# **Texture Analysis using GLCM**

# %% [markdown]
# Objective: Analyze an oral cavity image by extracting patches and computing texture features using the Grey Level Co-occurrence Matrix (GLCM).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from skimage.feature import greycomatrix, greycoprops

# Define GLCM feature names
feature_names = ['Contrast', 'Correlation', 'Energy', 'Homogeneity']

# Path to the dataset folder (update this)
dataset_path = "/content/drive/MyDrive/oral-cancer-screening-dataset/sample images"

# Get all image file names
image_files = [file for file in os.listdir(dataset_path)]

# %% [markdown]
# contrast → Measures intensity variation.
#
# correlation → Measures how correlated pixel pairs are.
#
# energy → Measures uniformity in texture.
#
# homogeneity → Measures how similar adjacent pixels are.

# %%
# Process each image
for img_name in image_files:
    img_path = os.path.join(dataset_path, img_name)

    # Read image and convert to grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

    # Compute GLCM
    glcm = greycomatrix(img, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)

    # Extract GLCM features
    contrast = greycoprops(glcm, 'contrast')[0, 0]
    correlation = greycoprops(glcm, 'correlation')[0, 0]
    energy = greycoprops(glcm, 'energy')[0, 0]
    homogeneity = greycoprops(glcm, 'homogeneity')[0, 0]

    # Store feature values
    feature_values = [contrast, correlation, energy, homogeneity]

    # Plot GLCM features for this image
    plt.figure(figsize=(6, 4))
    plt.bar(feature_names, feature_values, color=['red', 'blue', 'yellow', 'green'])
    plt.title(f'GLCM Features - {img_name}')
    plt.ylabel("Feature Value")
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/skimage/feature/__init__.py:35: skimage_deprecation: Function ``greycomatrix`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycomatrix`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.11/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.11/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# /usr/local/lib/python3.11/dist-packages/skimage/feature/__init__.py:42: skimage_deprecation: Function ``greycoprops`` is deprecated and will be removed in version 1.0. Use ``skimage.feature.graycoprops`` instead.
#   removed_version='1.0')
# ...

# %% [markdown]
# **EXAMPLE**

# %%
import matplotlib.pyplot as plt

from skimage.feature import graycomatrix, graycoprops
from skimage import data


PATCH_SIZE = 21

# open the camera image
image = data.camera()

# select some patches from grassy areas of the image
grass_locations = [(280, 454), (342, 223), (444, 192), (455, 455)]
grass_patches = []
for loc in grass_locations:
    grass_patches.append(
        image[loc[0] : loc[0] + PATCH_SIZE, loc[1] : loc[1] + PATCH_SIZE]
    )

# select some patches from sky areas of the image
sky_locations = [(38, 34), (139, 28), (37, 437), (145, 379)]
sky_patches = []
for loc in sky_locations:
    sky_patches.append(
        image[loc[0] : loc[0] + PATCH_SIZE, loc[1] : loc[1] + PATCH_SIZE]
    )

# compute some GLCM properties each patch
xs = []
ys = []
for patch in grass_patches + sky_patches:
    glcm = graycomatrix(
        patch, distances=[5], angles=[0], levels=256, symmetric=True, normed=True
    )
    xs.append(graycoprops(glcm, 'dissimilarity')[0, 0])
    ys.append(graycoprops(glcm, 'correlation')[0, 0])

# create the figure
fig = plt.figure(figsize=(8, 8))

# display original image with locations of patches
ax = fig.add_subplot(3, 2, 1)
ax.imshow(image, cmap=plt.cm.gray, vmin=0, vmax=255)
for y, x in grass_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'gs')
for y, x in sky_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'bs')
ax.set_xlabel('Original Image')
ax.set_xticks([])
ax.set_yticks([])
ax.axis('image')

# for each patch, plot (dissimilarity, correlation)
ax = fig.add_subplot(3, 2, 2)
ax.plot(xs[: len(grass_patches)], ys[: len(grass_patches)], 'go', label='Grass')
ax.plot(xs[len(grass_patches) :], ys[len(grass_patches) :], 'bo', label='Sky')
ax.set_xlabel('GLCM Dissimilarity')
ax.set_ylabel('GLCM Correlation')
ax.legend()

# display the image patches
for i, patch in enumerate(grass_patches):
    ax = fig.add_subplot(3, len(grass_patches), len(grass_patches) * 1 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray, vmin=0, vmax=255)
    ax.set_xlabel(f"Grass {i + 1}")

for i, patch in enumerate(sky_patches):
    ax = fig.add_subplot(3, len(sky_patches), len(sky_patches) * 2 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray, vmin=0, vmax=255)
    ax.set_xlabel(f"Sky {i + 1}")


# display the patches and plot
fig.suptitle('Grey level co-occurrence matrix features', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DOS**
# *   Load an Imge
# *   Convert to Grayscale
# *   Extract Patches
# *   Compute GLCM features
# *   Analyze and Compare Results
#
#
# *Bonus*
# *   Extract patches from multiple regions and analyze the variation in texture.
# *   Use different GLCM distances and angles to observe how the values change.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import graycomatrix

# Load Image
image_path = "/content/drive/MyDrive/oral-cancer-screening-dataset/sample images/C-9-1-7.jpg"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Display Image to Choose Patches
plt.imshow(image, cmap='gray')
plt.title("Select Patches Manually")
plt.show()

# Define Patch Size
PATCH_SIZE = 25

#Select Patches (Example Coordinates)
healthy_patch = image[100:100+PATCH_SIZE, 200:200+PATCH_SIZE]
affected_patch = image[300:300+PATCH_SIZE, 400:400+PATCH_SIZE]

#GLCM Features
glcm_healthy = graycomatrix(healthy_patch, distances=[5], angles=[0], levels=256, symmetric=True, normed=True)
glcm_lesion = graycomatrix(affected_patch, distances=[5], angles=[0], levels=256, symmetric=True, normed=True)

# Show Extracted Patches
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(healthy_patch, cmap='gray')
axes[0].set_title("Healthy Region Patch")
axes[1].imshow(affected_patch, cmap='gray')
axes[1].set_title("Affected Region Patch")
plt.show()

# %%
import matplotlib.pyplot as plt

from skimage.feature import graycomatrix, graycoprops
from skimage import data, io,color


PATCH_SIZE = 21

# open the camera image
image = io.imread('/content/drive/MyDrive/oral-cancer-screening-dataset/sample images/C-9-1-7.jpg')
image = color.rgb2gray(image)
image = (image * 255).astype('uint8')

# select some patches from grassy areas of the image
grass_locations = [(280, 454), (342, 223), (444, 192), (455, 455)]
grass_patches = []
for loc in grass_locations:
    grass_patches.append(
        image[loc[0] : loc[0] + PATCH_SIZE, loc[1] : loc[1] + PATCH_SIZE]
    )

# select some patches from sky areas of the image
sky_locations = [(38, 34), (139, 28), (37, 437), (145, 379)]
sky_patches = []
for loc in sky_locations:
    sky_patches.append(
        image[loc[0] : loc[0] + PATCH_SIZE, loc[1] : loc[1] + PATCH_SIZE]
    )

# compute some GLCM properties each patch
xs = []
ys = []
for patch in grass_patches + sky_patches:
    glcm = graycomatrix(
        patch, distances=[5], angles=[0], levels=256, symmetric=True, normed=True
    )
    xs.append(graycoprops(glcm, 'dissimilarity')[0, 0])
    ys.append(graycoprops(glcm, 'correlation')[0, 0])

# create the figure
fig = plt.figure(figsize=(8, 8))

# display original image with locations of patches
ax = fig.add_subplot(3, 2, 1)
ax.imshow(image, cmap=plt.cm.gray, vmin=0, vmax=255)
for y, x in grass_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'gs')
for y, x in sky_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'bs')
ax.set_xlabel('Original Image')
ax.set_xticks([])
ax.set_yticks([])
ax.axis('image')

# for each patch, plot (dissimilarity, correlation)
ax = fig.add_subplot(3, 2, 2)
ax.plot(xs[: len(grass_patches)], ys[: len(grass_patches)], 'go', label='Grass')
ax.plot(xs[len(grass_patches) :], ys[len(grass_patches) :], 'bo', label='Sky')
ax.set_xlabel('GLCM Dissimilarity')
ax.set_ylabel('GLCM Correlation')
ax.legend()

# display the image patches
for i, patch in enumerate(grass_patches):
    ax = fig.add_subplot(3, len(grass_patches), len(grass_patches) * 1 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray, vmin=0, vmax=255)
    ax.set_xlabel(f"Grass {i + 1}")

for i, patch in enumerate(sky_patches):
    ax = fig.add_subplot(3, len(sky_patches), len(sky_patches) * 2 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray, vmin=0, vmax=255)
    ax.set_xlabel(f"Sky {i + 1}")


# display the patches and plot
fig.suptitle('Grey level co-occurrence matrix features', fontsize=14, y=1.05)
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
